# %%
# tutorial step graph:
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/step_demo.html
import matplotlib.pyplot as plt
import numpy as np

# %%
# bikin sinyal , output ke csv

# %%
#jalankan simulator di C, output ke toggle_output.csv
import pandas as pd
df = pd.read_csv('geser.csv')

# %%
# figure size: https://matplotlib.org/stable/gallery/subplots_axes_and_figures/figure_size_units.html
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
# plt.subplots(figsize=(8, 4))
# multiple subgraph demo: https://matplotlib.org/stable/gallery/subplots_axes_and_figures/multiple_figs_demo.html
plt.figure(figsize=(10,8))
plt.subplot(411)
plt.step(df["k"], df["geser_input_kiri"], where='post',color = 'green', label = "input") 
plt.plot(df["k"], df["geser_input_kiri"], 'o',color = 'green', label = "input", alpha=0.3) 
plt.subplot(412)
plt.step(df["k"], df["geser_input_kanan"], where='post',color = 'blue', label = "input") 
plt.plot(df["k"], df["geser_input_kanan"], 'o',color = 'blue', label = "input", alpha=0.3) 
plt.subplot(413)
plt.step(df["k"], df["geser_state"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["geser_state"], 'o',color = 'red', label = "input", alpha=0.3) 
plt.subplot(414)
plt.step(df["k"], df["geser_output"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["geser_output"], 'o',color = 'red', label = "input", alpha=0.3) 

#plt.step(x, y, where='post', label='post')
plt.savefig("geser.jpg")
plt.show()

# %%
import pandas as pd
df = pd.read_csv('edge.csv')

# %%
plt.figure(figsize=(10,8))
plt.subplot(311)
plt.step(df["k"], df["edge_input"], where='post',color = 'green', label = "input") 
plt.plot(df["k"], df["edge_input"], 'o',color = 'green', label = "input", alpha=0.3) 
plt.subplot(312)
plt.step(df["k"], df["edge_state"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["edge_state"], 'o',color = 'red', label = "input", alpha=0.3) 
plt.subplot(313)
plt.step(df["k"], df["edge_output"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["edge_output"], 'o',color = 'red', label = "input", alpha=0.3) 

#plt.step(x, y, where='post', label='post')
plt.savefig("edge.jpg")
plt.show()

# %%
import pandas as pd
df = pd.read_csv('debounce.csv')

# %%
plt.figure(figsize=(10,8))
plt.subplot(411)
plt.step(df["k"], df["input"], where='post',color = 'green', label = "input") 
plt.plot(df["k"], df["input"], 'o',color = 'green', label = "input", alpha=0.3) 
plt.subplot(412)
plt.step(df["k"], df["state"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["state"], 'o',color = 'red', label = "input", alpha=0.3) 
plt.subplot(413)
plt.step(df["k"], df["counter"], where='post',color = 'black', label = "output") 
plt.plot(df["k"], df["counter"], 'o',color = 'black', label = "input", alpha=0.3) 
# plt.set_ylim([0, 10])
#plt.ylim(top=15) #ymax is your value
plt.subplot(414)
plt.step(df["k"], df["output"], where='post',color = 'red', label = "output") 
plt.plot(df["k"], df["output"], 'o',color = 'red', label = "input", alpha=0.3) 

#plt.step(x, y, where='post', label='post')
plt.savefig("edge.jpg")
plt.show()
